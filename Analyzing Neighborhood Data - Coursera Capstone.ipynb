# %% [markdown]
# ### Analyzing Neighborhood Data - Coursera Capstone Project

# %% [markdown]
# This notebook will be used for carrying out Analysis of Neighborhood Data a Capstone Project of the Coursera IBM Data Science Course

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
