# %% [markdown]
# ### What is the best Place to Launch a Restaurant in Nairobi County, Kenya?? Analysis

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Topic: What would be the best Location to Open a Restaurant in Nairobi City, Kenya - Africa
#
# Kenya's capital city, Nairobi, is the most dynamic city in East Africa, also known as "green city in the sun". Its kenya's largest city and has a population of nearly 4 million. As the largest center of business and trade in East Africa and a regional location of various international companies and organizations, Nairobi has amased alot of interests from investors looking to launch restaurants, hotel, lodges and budget accommodations but the big question is: **What would be the best location to set up a restaurant that is likely to guarantee a return on investement within Nairobi?** and **What are the major factors that contribute to the setup of restaurants in a particular location within Nairobi Town?**

# %%
## Importing the required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from geopy.geocoders import Nominatim

sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(10, 8)})

# %% [markdown]
# ### Lets get the Latitude and Longitude of Nairobi, Kenya

# %%
address = 'Nairobi, Kenya'

geolocator = Nominatim(user_agent="nairobi_explore")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Nairobi are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Nairobi are -1.2832533, 36.8172449.

# %% [markdown]
# ### Import Data with Longitudes and Latitudes

# %%
import os
os.listdir()
# Out:
# []

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Unnamed: 0 Constituency                  Wards  Latitude  Longitude
# 0           0    Westlands              Kitisuru  -1.239554  36.783965
# 1           1    Westlands   Parklands/Highridge  -1.263062  36.810629
# 2           2    Westlands                Karura  -1.236988  36.832559
# 3           3    Westlands               Kangemi  -1.265426  36.752518
# 4           4    Westlands          Mountain View -1.271131  36.743003

# %%
# nairobi_df = pd.read_csv("constituency_ward_lat_long.csv")
# nairobi_df.head()

# %%
# Remove unwanted Unnamed Column
nairobi_df.drop(columns=["Unnamed: 0"], inplace=True)
nairobi_df.head()
# Out:
#   Constituency                  Wards  Latitude  Longitude
# 0    Westlands              Kitisuru  -1.239554  36.783965
# 1    Westlands   Parklands/Highridge  -1.263062  36.810629
# 2    Westlands                Karura  -1.236988  36.832559
# 3    Westlands               Kangemi  -1.265426  36.752518
# 4    Westlands          Mountain View -1.271131  36.743003

# %% [markdown]
# ### A Mapping of all the Constituencies

# %%
map_nairobi = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(nairobi_df['Latitude'], nairobi_df['Longitude'], nairobi_df['Wards']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_nairobi)  
    
map_nairobi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Lets have a look at the Dataframe

# %%
nairobi_df.head()
# Out:
#   Constituency                  Wards  Latitude  Longitude
# 0    Westlands              Kitisuru  -1.239554  36.783965
# 1    Westlands   Parklands/Highridge  -1.263062  36.810629
# 2    Westlands                Karura  -1.236988  36.832559
# 3    Westlands               Kangemi  -1.265426  36.752518
# 4    Westlands          Mountain View -1.271131  36.743003

# %% [markdown]
# #### Get all the Unique Ward

# %%
nairobi_df.Wards.unique()
# Out:
# array(['Kitisuru\xa0', ' Parklands/Highridge\xa0', ' Karura\xa0',
#        ' Kangemi\xa0', ' Mountain View', 'Kilimani\xa0', ' Kawangware\xa0',
#        ' Gatina\xa0', ' Kileleshwa\xa0', ' Kabiro', 'Mutu-ini\xa0',
#        ' Riruta\xa0', ' Uthiru/Ruthimitu\xa0', ' Waithaka', 'Karen\xa0',
#        ' Nairobi West\xa0', ' Mugumo-ini\xa0', ' South C\xa0',
#        ' Nyayo Highrise', 'Laini Saba\xa0', ' Lindi\xa0', ' Makina\xa0',
#        ' Woodley/Kenyatta Golf Course\xa0', " Sarang'ombe", 'Githurai\xa0',
#        ' Kahawa West\xa0', ' Zimmerman\xa0', ' Roysambu\xa0', ' Kahawa',
#        'Clay City\xa0', ' Mwiki\xa0', ' Kasarani\xa0', ' Njiru\xa0',
#        ' Ruai', 'Babadogo\xa0', ' Utalii\xa0', ' Mathare North\xa0',
#        ' Lucky Summer\xa0', ' Korogocho', 'Imara Daima\xa0',
#        ' Kwa Njenga\xa0', ' Kwa Reuben\xa0', ' Pipeline\xa0', ' Kware',
#        'Kariobangi North\xa0', ' Dandora Area I\xa0',
#        ' Dandora Area II\xa0', ' Dandora Area III\xa0', ' Dandora Area IV',
#        'Kayole North\xa0', ' Kayole Central\xa0', ' Kayole South\xa0',
#        ' Komarock\xa0', ' Matopeni/Spring Valley', 'Upper Savanna\xa0',
#        ' Lower Savanna\xa0', ' Embakasi\xa0', ' Utawala\xa0', " Mihang'o",
#        'Umoja I\xa0', ' Umoja II\xa0', ' Mowlem\xa0', ' Kariobangi South',
#        'Makongeni\xa0', ' Maringo/Hamza\xa0', ' Harambee\xa0',
#        ' Viwandani', 'Pumwani\xa0', ' Eastleigh North\xa0',
#        ' Eastleigh South\xa0', 'Nairobi Central\xa0', ' Ngara\xa0',
#        ' Ziwani/Kariokor\xa0', ' Pangani\xa0', ' Landimawe\xa0',
#        ' Nairobi South', 'Hospital\xa0', ' Mabatini\xa0', ' Huruma\xa0',
#        ' Ngei\xa0', ' Mlango Kubwa\xa0', ' Kiamaiko'], dtype=object)

# %% [markdown]
# #### Clean the Wards Data i.e. Remove \xa0

# %%
def clean_string(x):
    return x.replace(u'\xa0', ' ').encode('utf-8').decode('utf-8').strip()

# Testing clean_string
print(clean_string("Kitisuru\xa0"))
# Out:
# Kitisuru

# %%
nairobi_df.Wards = nairobi_df.Wards.apply(clean_string)
nairobi_df.Wards.values
# Out:
# array(['Kitisuru', 'Parklands/Highridge', 'Karura', 'Kangemi',
#        'Mountain View', 'Kilimani', 'Kawangware', 'Gatina', 'Kileleshwa',
#        'Kabiro', 'Mutu-ini', 'Riruta', 'Uthiru/Ruthimitu', 'Waithaka',
#        'Karen', 'Nairobi West', 'Mugumo-ini', 'South C', 'Nyayo Highrise',
#        'Laini Saba', 'Lindi', 'Makina', 'Woodley/Kenyatta Golf Course',
#        "Sarang'ombe", 'Githurai', 'Kahawa West', 'Zimmerman', 'Roysambu',
#        'Kahawa', 'Clay City', 'Mwiki', 'Kasarani', 'Njiru', 'Ruai',
#        'Babadogo', 'Utalii', 'Mathare North', 'Lucky Summer', 'Korogocho',
#        'Imara Daima', 'Kwa Njenga', 'Kwa Reuben', 'Pipeline', 'Kware',
#        'Kariobangi North', 'Dandora Area I', 'Dandora Area II',
#        'Dandora Area III', 'Dandora Area IV', 'Kayole North',
#        'Kayole Central', 'Kayole South', 'Komarock',
#        'Matopeni/Spring Valley', 'Upper Savanna', 'Lower Savanna',
#        'Embakasi', 'Utawala', "Mihang'o", 'Umoja I', 'Umoja II', 'Mowlem',
#        'Kariobangi South', 'Makongeni', 'Maringo/Hamza', 'Harambee',
#        'Viwandani', 'Pumwani', 'Eastleigh North', 'Eastleigh South',
#        'Nairobi Central', 'Ngara', 'Ziwani/Kariokor', 'Pangani',
#        'Landimawe', 'Nairobi South', 'Hospital', 'Mabatini', 'Huruma',
#        'Ngei', 'Mlango Kubwa', 'Kiamaiko'], dtype=object)

# %%
nairobi_df.head()
# Out:
#   Constituency                Wards  Latitude  Longitude
# 0    Westlands             Kitisuru -1.239554  36.783965
# 1    Westlands  Parklands/Highridge -1.263062  36.810629
# 2    Westlands               Karura -1.236988  36.832559
# 3    Westlands              Kangemi -1.265426  36.752518
# 4    Westlands        Mountain View -1.271131  36.743003

# %% [markdown]
# ### Setting Up FourSquare Credentials

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentails:
# CLIENT_ID: QGIGC40OIPFLAHA4SZRPLBFFNM1QXA4V2G2LQW5244VYY50P
# CLIENT_SECRET:QSE3UMXWQFRONXR4SACUKZJ1HY3HMVYZM1IOT3B1EZXWN0YQ

# %% [markdown]
# ### Exploring the First Ward

# %%
nairobi_df.iloc[0]
# Out:
# Constituency     Westlands
# Wards             Kitisuru
# Latitude          -1.23955
# Longitude           36.784
# Name: 0, dtype: object

# %%
kitusuru_lat = nairobi_df.loc[0, "Latitude"]
kitusuru_long = nairobi_df.loc[0, "Longitude"]
print("Kitusuru Latitude {}, Kitusuru Longitude {}".format(kitusuru_lat, kitusuru_long))
# Out:
# Kitusuru Latitude -1.2395542, Kitusuru Longitude 36.7839651

# %% [markdown]
# ### Lets fetch the top 100 venues around Kitusuru, within a radius of 500 metres

# %%
# FourSquare Query URL
LIMIT=100
radius=500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    kitusuru_lat, 
    kitusuru_long, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=QGIGC40OIPFLAHA4SZRPLBFFNM1QXA4V2G2LQW5244VYY50P&client_secret=QSE3UMXWQFRONXR4SACUKZJ1HY3HMVYZM1IOT3B1EZXWN0YQ&v=20180605&ll=-1.2395542,36.7839651&radius=500&limit=100'

# %%
# Request Library
import requests

# send request
results = requests.get(url).json()
results["response"]['groups'][0]['items']
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-504b3e83e4b05763e991e17c-0',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1ed941735',
#      'name': 'Spa',
#      'pluralName': 'Spas',
#      'primary': True,
#      'shortName': 'Spa'}],
#    'id': '504b3e83e4b05763e991e17c',
#    'location': {'cc': 'KE',
#     'country': 'Kenya',
#     'distance': 291,
#     'formattedAddress': ['Kenya'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': -1.2395993225322157,
#       'lng': 36.781348250500564}],
#     'lat': -1.2395993225322157,
#     'lng': 36.781348250500564},
#    'name': 'Spa Exhale',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-59edd31f7564f74cb2345108-1',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1fd941735',
#      'name': 'Shopping Mall',
#      'pluralName': 'Shopping Malls',
#      'primary': True,
#      'shortName': 'Mall'}],
#    'id': '59edd31f7564f74cb2345108',
#    'location': {'cc': 'KE',
#     'country': 'Kenya',
#     'distance': 333,
#     'formattedAddress': ['Kenya'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': -1.2388544,
#       'lng': 36.78105}],
#     'lat': -1.2388544,
#     'lng': 36.78105},
#    'name': 'Spinners Web',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-51e03be2498e4f91871ea971-2',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d120941735',
#      'name': 'Karaoke Bar',
#      'pluralName': 'Karaoke Bars',
#      'primary': True,
#      'shortName': 'Karaoke'}],
#    'id': '51e03be2498e4f91871ea971',
#    'location': {'cc': 'KE',
#     'country': 'Kenya',
#     'distance': 452,
#     'formattedAddress': ['Kenya'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': -1.239399089922266,
#       'lng': 36.77990174122698}],
#     'lat': -1.239399089922266,
#     'lng': 36.77990174122698},
#    'name': 'Kitusuru holiday resort',
#    'photos': {'count': 0, 'groups': []}}}]

# %%
# venues within 500m of Kitusuru
for row in results["response"]['groups'][0]['items']:
    print(row['venue']['categories'][0]['name'])
# Out:
# Spa
# Shopping Mall
# Karaoke Bar

# %% [markdown]
# ### Lets fetch the top 100 venues around each Ward within a radius of 500 metres

# %%
# Helper Function: Fetch Categories
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ## Exploring the venues in Nairobi Wards

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# get nearby venues
nairobi_venues = getNearbyVenues(names=nairobi_df["Wards"], 
                                 latitudes=nairobi_df["Latitude"], 
                                 longitudes=nairobi_df["Longitude"])
# Out:
# Kitisuru
# Parklands/Highridge
# Karura
# Kangemi
# Mountain View
# Kilimani
# Kawangware
# Gatina
# Kileleshwa
# Kabiro
# Mutu-ini
# Riruta
# Uthiru/Ruthimitu
# Waithaka
# Karen
# Nairobi West
# Mugumo-ini
# South C
# Nyayo Highrise
# Laini Saba
# Lindi
# Makina
# Woodley/Kenyatta Golf Course
# Sarang'ombe
# Githurai
# Kahawa West
# Zimmerman
# Roysambu
# Kahawa
# Clay City
# Mwiki
# Kasarani
# Njiru
# Ruai
# Babadogo
# Utalii
# Mathare North
# Lucky Summer
# Korogocho
# Imara Daima
# Kwa Njenga
# Kwa Reuben
# Pipeline
# Kware
# Kariobangi North
# Dandora Area I
# Dandora Area II
# Dandora Area III
# Dandora Area IV
# Kayole North
# Kayole Central
# Kayole South
# Komarock
# Matopeni/Spring Valley
# Upper Savanna
# Lower Savanna
# Embakasi
# Utawala
# Mihang'o
# Umoja I
# Umoja II
# Mowlem
# Kariobangi South
# Makongeni
# Maringo/Hamza
# Harambee
# Viwandani
# Pumwani
# Eastleigh North
# Eastleigh South
# Nairobi Central
# Ngara
# Ziwani/Kariokor
# Pangani
# Landimawe
# Nairobi South
# Hospital
# Mabatini
# Huruma
# Ngei
# Mlango Kubwa
# Kiamaiko

# %% [markdown]
# #### Lets have a look at the Venues Data

# %%
nairobi_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     Kitisuru              -1.239554               36.783965
# 1     Kitisuru              -1.239554               36.783965
# 2     Kitisuru              -1.239554               36.783965
# 3     Kitisuru              -1.239554               36.783965
# 4     Kitisuru              -1.239554               36.783965
#
#                           Venue  Venue Latitude  Venue Longitude  \
# 0                  Spinners Web       -1.238854        36.781050
# 1       Kitusuru holiday resort       -1.239399        36.779902
# 2                     Oasis BnB       -1.241327        36.792136
# 3  Sno Sundae Ice Cream Parlour       -1.238083        36.792667
# 4      Karura forest, (Sigiria)       -1.240438        36.792890
#
#     Venue Category
# 0    Shopping Mall
# 1      Karaoke Bar
# 2  Bed & Breakfast
# 3     Dessert Shop
# 4           Forest

# %% [markdown]
# #### Lets have a look at the Number of Generated Venues

# %%
nairobi_venues.shape
# Out:
# (1054, 7)

# %%
# Lets have a look at the venues per Neighborhood
nairobi_venues.groupby('Neighborhood').count()
# Out:
#                               Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# Babadogo                                          5                       5
# Clay City                                        15                      15
# Dandora Area I                                    3                       3
# Dandora Area II                                   3                       3
# Dandora Area III                                  3                       3
# Dandora Area IV                                   3                       3
# Eastleigh North                                  12                      12
# Eastleigh South                                  12                      12
# Embakasi                                         13                      13
# Gatina                                            1                       1
# Githurai                                          8                       8
# Harambee                                         14                      14
# Hospital                                          8                       8
# Huruma                                            5                       5
# Imara Daima                                      11                      11
# Kabiro                                            2                       2
# Kahawa                                            1                       1
# Kahawa West                                       7                       7
# Kangemi                                           5                       5
# Karen                                            35                      35
# Kariobangi North                                  4                       4
# Kariobangi South                                 13                      13
# Karura                                            2                       2
# Kasarani                                         15                      15
# Kayole Central                                   10                      10
# Kayole North                                     10                      10
# Kayole South                                     10                      10
# Kiamaiko                                          4                       4
# Kileleshwa                                       49                      49
# Kilimani                                         51                      51
# ...                                             ...                     ...
# Mowlem                                           13                      13
# Mugumo-ini                                        4                       4
# Mutu-ini                                          1                       1
# Mwiki                                             4                       4
# Nairobi Central                                  76                      76
# Nairobi South                                    44                      44
# Nairobi West                                     45                      45
# Ngara                                            38                      38
# Ngei                                              5                       5
# Njiru                                             3                       3
# Nyayo Highrise                                   24                      24
# Pangani                                          16                      16
# Parklands/Highridge                              96                      96
# Pumwani                                          13                      13
# Riruta                                            6                       6
# Roysambu                                         26                      26
# Ruai                                              4                       4
# Sarang'ombe                                       5                       5
# South C                                          35                      35
# Umoja I                                          12                      12
# Umoja II                                         16                      16
# Upper Savanna                                    13                      13
# Utalii                                           10                      10
# Utawala                                           2                       2
# Uthiru/Ruthimitu                                  6                       6
# Viwandani                                         4                       4
# Waithaka                                          3                       3
# Woodley/Kenyatta Golf Course                     22                      22
# Zimmerman                                        17                      17
# Ziwani/Kariokor                                   8                       8
#
#                               Venue  Venue Latitude  Venue Longitude  \
# Neighborhood
# Babadogo                          5               5                5
# Clay City                        15              15               15
# Dandora Area I                    3               3                3
# Dandora Area II                   3               3                3
# Dandora Area III                  3               3                3
# Dandora Area IV                   3               3                3
# Eastleigh North                  12              12               12
# Eastleigh South                  12              12               12
# Embakasi                         13              13               13
# Gatina                            1               1                1
# Githurai                          8               8                8
# Harambee                         14              14               14
# Hospital                          8               8                8
# Huruma                            5               5                5
# Imara Daima                      11              11               11
# Kabiro                            2               2                2
# Kahawa                            1               1                1
# Kahawa West                       7               7                7
# Kangemi                           5               5                5
# Karen                            35              35               35
# Kariobangi North                  4               4                4
# Kariobangi South                 13              13               13
# Karura                            2               2                2
# Kasarani                         15              15               15
# Kayole Central                   10              10               10
# Kayole North                     10              10               10
# Kayole South                     10              10               10
# Kiamaiko                          4               4                4
# Kileleshwa                       49              49               49
# Kilimani                         51              51               51
# ...                             ...             ...              ...
# Mowlem                           13              13               13
# Mugumo-ini                        4               4                4
# Mutu-ini                          1               1                1
# Mwiki                             4               4                4
# Nairobi Central                  76              76               76
# Nairobi South                    44              44               44
# Nairobi West                     45              45               45
# Ngara                            38              38               38
# Ngei                              5               5                5
# Njiru                             3               3                3
# Nyayo Highrise                   24              24               24
# Pangani                          16              16               16
# Parklands/Highridge              96              96               96
# Pumwani                          13              13               13
# Riruta                            6               6                6
# Roysambu                         26              26               26
# Ruai                              4               4                4
# Sarang'ombe                       5               5                5
# South C                          35              35               35
# Umoja I                          12              12               12
# Umoja II                         16              16               16
# Upper Savanna                    13              13               13
# Utalii                           10              10               10
# Utawala                           2               2                2
# Uthiru/Ruthimitu                  6               6                6
# Viwandani                         4               4                4
# Waithaka                          3               3                3
# Woodley/Kenyatta Golf Course     22              22               22
# Zimmerman                        17              17               17
# Ziwani/Kariokor                   8               8                8
#
#                               Venue Category
# Neighborhood
# Babadogo                                   5
# Clay City                                 15
# Dandora Area I                             3
# Dandora Area II                            3
# Dandora Area III                           3
# Dandora Area IV                            3
# Eastleigh North                           12
# Eastleigh South                           12
# Embakasi                                  13
# Gatina                                     1
# Githurai                                   8
# Harambee                                  14
# Hospital                                   8
# Huruma                                     5
# Imara Daima                               11
# Kabiro                                     2
# Kahawa                                     1
# Kahawa West                                7
# Kangemi                                    5
# Karen                                     35
# Kariobangi North                           4
# Kariobangi South                          13
# Karura                                     2
# Kasarani                                  15
# Kayole Central                            10
# Kayole North                              10
# Kayole South                              10
# Kiamaiko                                   4
# Kileleshwa                                49
# Kilimani                                  51
# ...                                      ...
# Mowlem                                    13
# Mugumo-ini                                 4
# Mutu-ini                                   1
# Mwiki                                      4
# Nairobi Central                           76
# Nairobi South                             44
# Nairobi West                              45
# Ngara                                     38
# Ngei                                       5
# Njiru                                      3
# Nyayo Highrise                            24
# Pangani                                   16
# Parklands/Highridge                       96
# Pumwani                                   13
# Riruta                                     6
# Roysambu                                  26
# Ruai                                       4
# Sarang'ombe                                5
# South C                                   35
# Umoja I                                   12
# Umoja II                                  16
# Upper Savanna                             13
# Utalii                                    10
# Utawala                                    2
# Uthiru/Ruthimitu                           6
# Viwandani                                  4
# Waithaka                                   3
# Woodley/Kenyatta Golf Course              22
# Zimmerman                                 17
# Ziwani/Kariokor                            8
#
# [80 rows x 6 columns]

# %%
# Number of Unique Categories of Venues
len(nairobi_venues["Venue Category"].unique())
# Out:
# 144

# %%
# Since we are doing an analysis of restaurants we'll focus on a number of categories
# Lets have a look at the categories
nairobi_venues["Venue Category"].unique()
# Out:
# array(['Shopping Mall', 'Karaoke Bar', 'Bed & Breakfast', 'Dessert Shop',
#        'Forest', 'BBQ Joint', 'Hotel', 'Nightclub', 'Brewery',
#        'Seafood Restaurant', 'Café', 'Burger Joint', 'Bakery',
#        'Beer Garden', 'Gym / Fitness Center', 'Indian Restaurant', 'Bar',
#        'Sports Bar', 'Lounge', 'Italian Restaurant', 'African Restaurant',
#        'Japanese Restaurant', 'Ice Cream Shop', 'Bookstore', 'Bistro',
#        'Chinese Restaurant', 'Donut Shop', 'Mexican Restaurant',
#        'Pizza Place', 'Coffee Shop', 'Pub', 'Gaming Cafe', 'Supermarket',
#        'Cocktail Bar', 'Hotel Bar', 'Falafel Restaurant',
#        'Fried Chicken Joint', 'Gym', 'Food Court', 'Fast Food Restaurant',
#        'Mediterranean Restaurant', 'Gas Station', 'Department Store',
#        'Steakhouse', 'Gift Shop', 'Restaurant', 'Grocery Store',
#        'Golf Course', 'Video Store', 'Bus Station', 'Food',
#        'Indie Movie Theater', 'Convenience Store', 'Brazilian Restaurant',
#        'Art Gallery', 'Ethiopian Restaurant', 'Middle Eastern Restaurant',
#        'Resort', 'Juice Bar', 'New American Restaurant', 'Sandwich Place',
#        'Pool', 'Housing Development', 'Hookah Bar', 'Diner', 'Salad Place',
#        'Thai Restaurant', 'Park', 'Farmers Market', 'College Cafeteria',
#        'Lawyer', 'Arts & Crafts Store', 'Video Game Store', 'Market',
#        'Burrito Place', 'Clothing Store', 'Flea Market',
#        'Spanish Restaurant', 'Snack Place', 'Shoe Store', 'Garden Center',
#        'Fruit & Vegetable Store', 'Multiplex', 'Gastropub', 'Stadium',
#        'Food & Drink Shop', 'Airport Lounge', 'Pharmacy',
#        'Mobile Phone Shop', 'History Museum', 'Basketball Court',
#        'Sports Club', 'Farm', 'Campground', 'Airport Terminal',
#        'Pet Store', 'Fish Market', 'Whisky Bar', 'Airport',
#        'Fish & Chips Shop', 'Soccer Stadium', 'Tennis Court',
#        'Cupcake Shop', 'Auto Garage', 'Train Station',
#        'Athletics & Sports', 'Smoke Shop', 'Sculpture Garden',
#        'Moving Target', 'Baseball Field', 'Breakfast Spot', 'Sausage Shop',
#        'Bridal Shop', 'Rest Area', 'Soccer Field', 'Bus Stop',
#        'Outdoor Sculpture', 'Furniture / Home Store', 'Electronics Store',
#        'Vegetarian / Vegan Restaurant', 'Shop & Service', "Men's Store",
#        'Movie Theater', 'Nightlife Spot', 'Outlet Mall', 'Arcade',
#        'Boutique', 'Performing Arts Venue', 'Eastern European Restaurant',
#        'Turkish Restaurant', 'Kebab Restaurant', 'Buffet', 'Wine Bar',
#        'Theater', 'Hotel Pool', 'Motel', 'Travel & Transport',
#        'Playground', 'Cosmetics Shop', 'Music Venue', 'Pier',
#        'Event Space', 'Szechuan Restaurant', 'Light Rail Station'], dtype=object)

# %%
# We are first going to locate all the Restaurants, Resorts and Hotels in Nairobi and map them to see their distribution we'll already view empty areas and congested areas
# Create Boolean Filters

nairobi_restaurants = nairobi_venues[nairobi_venues["Venue Category"].str.contains("Restaurant") | nairobi_venues["Venue Category"].str.contains("Resort") \
                                     | nairobi_venues["Venue Category"].str.contains("Hotel")]

# %%
nairobi_restaurants.head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 6   Parklands/Highridge              -1.263062               36.810629
# 7   Parklands/Highridge              -1.263062               36.810629
# 10  Parklands/Highridge              -1.263062               36.810629
# 17  Parklands/Highridge              -1.263062               36.810629
# 18  Parklands/Highridge              -1.263062               36.810629
#
#                      Venue  Venue Latitude  Venue Longitude  \
# 6     Southern Sun Mayfair       -1.262520        36.808652
# 7   La Maison Royale Hotel       -1.265329        36.808667
# 10  Ocean Basket @The Oval       -1.258567        36.805579
# 17    Villa Rosa Kempinski       -1.271530        36.808799
# 18                Chowpaty       -1.265624        36.805119
#
#         Venue Category
# 6                Hotel
# 7                Hotel
# 10  Seafood Restaurant
# 17               Hotel
# 18   Indian Restaurant

# %% [markdown]
# ## Mapping of Restaurants, Hotels and Resorts in Nairobi

# %%
address = 'Nairobi, Kenya'

geolocator = Nominatim(user_agent="nairobi_explore")
location = geolocator.geocode(address)
nrb_latitude = location.latitude
nrb_longitude = location.longitude
print('The geograpical coordinate of Nairobi are {}, {}.'.format(latitude, longitude))

map_nairobi = folium.Map(location=[nrb_latitude, nrb_longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(nairobi_restaurants['Venue Latitude'], nairobi_restaurants['Venue Longitude'], nairobi_restaurants['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#00A86B',
        fill_opacity=0.7).add_to(map_nairobi)  
    
map_nairobi
# Out:
# The geograpical coordinate of Nairobi are -1.2832533, 36.8172449.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# From the map above we can already identify that areas around Kilimani, Westlands and Nairobi Central have the highest amount of Restaurants, Hotels and Resorts
# Lets do a Cluster Analysis based on (latitude, longitude) using DBSCAN to cluster the coordinates then drill down on each or the locations

# %%
# Importing clustering libraries
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from geopy.distance import great_circle
from shapely.geometry import MultiPoint

# %%
nairobi_restaurants.head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 6   Parklands/Highridge              -1.263062               36.810629
# 7   Parklands/Highridge              -1.263062               36.810629
# 10  Parklands/Highridge              -1.263062               36.810629
# 17  Parklands/Highridge              -1.263062               36.810629
# 18  Parklands/Highridge              -1.263062               36.810629
#
#                      Venue  Venue Latitude  Venue Longitude  \
# 6     Southern Sun Mayfair       -1.262520        36.808652
# 7   La Maison Royale Hotel       -1.265329        36.808667
# 10  Ocean Basket @The Oval       -1.258567        36.805579
# 17    Villa Rosa Kempinski       -1.271530        36.808799
# 18                Chowpaty       -1.265624        36.805119
#
#         Venue Category
# 6                Hotel
# 7                Hotel
# 10  Seafood Restaurant
# 17               Hotel
# 18   Indian Restaurant

# %%
# Get restaurants coordinates
# coords = nairobi_restaurants.as_matrix(columns=['Venue Latitude', 'Venue Longitude'])
coords = nairobi_restaurants[['Venue Latitude', 'Venue Longitude']].values
coords[:5]
# Out:
# array([[ -1.26252044,  36.80865215],
#        [ -1.26532889,  36.80866652],
#        [ -1.25856723,  36.80557865],
#        [ -1.27152987,  36.80879888],
#        [ -1.2656237 ,  36.80511865]])

# %% [markdown]
# ## Clustering points within a maximum distance of 3 kilometers - Algorithm DBSCAN

# %%
kms_per_radian = 6371.0088
epsilon = 1.0 / kms_per_radian # Max distance points can be from each other
db = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree', metric='haversine').fit(np.radians(coords))

cluster_labels = db.labels_
num_clusters = len(set(cluster_labels))
clusters = pd.Series([coords[cluster_labels == n] for n in range(num_clusters)])
print('Number of clusters: {}'.format(num_clusters))
# Out:
# Number of clusters: 25

# %%
# Getting Centermost Points per Cluster
def get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
    return tuple(centermost_point)

centermost_points = clusters.map(get_centermost_point)
centermost_points
# Out:
# 0     (-1.27158157288, 36.8100347999)
# 1     (-1.26363205886, 36.7431351451)
# 2     (-1.29119835198, 36.7852215216)
# 3     (-1.28875142903, 36.7558113546)
# 4     (-1.28629000785, 36.7408300489)
# 5     (-1.32296644397, 36.7033482099)
# 6     (-1.33627965062, 36.7048860116)
# 7               (-1.314171, 36.82828)
# 8              (-1.2015663, 36.83931)
# 9     (-1.31618021231, 36.8070861259)
# 10    (-1.19335804068, 36.9015461262)
# 11    (-1.21821992363, 36.8962997782)
# 12    (-1.25608077055, 36.9265333397)
# 13    (-1.26649833405, 36.9902989665)
# 14    (-1.25834159013, 36.8540370024)
# 15    (-1.31495429486, 36.8653497312)
# 16     (-1.26921623251, 36.911601891)
# 17     (-1.2522543037, 36.7963481996)
# 18    (-1.32827845771, 36.8927074679)
# 19    (-1.28083409075, 36.8962931682)
# 20    (-1.28961211097, 36.9011495364)
# 21         (-1.28770909, 36.87383814)
# 22    (-1.27980251541, 36.8481776604)
# 23    (-1.26371592479, 36.8384611382)
# 24     (-1.2600705636, 36.8743020006)
# dtype: object

# %%
# Add the clusters to the nairobi_restaurants dataframe
nairobi_restaurants["cluster"] = cluster_labels
nairobi_restaurants.reset_index().head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#    index         Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0      6  Parklands/Highridge              -1.263062               36.810629
# 1      7  Parklands/Highridge              -1.263062               36.810629
# 2     10  Parklands/Highridge              -1.263062               36.810629
# 3     17  Parklands/Highridge              -1.263062               36.810629
# 4     18  Parklands/Highridge              -1.263062               36.810629
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0    Southern Sun Mayfair       -1.262520        36.808652
# 1  La Maison Royale Hotel       -1.265329        36.808667
# 2  Ocean Basket @The Oval       -1.258567        36.805579
# 3    Villa Rosa Kempinski       -1.271530        36.808799
# 4                Chowpaty       -1.265624        36.805119
#
#        Venue Category  cluster
# 0               Hotel        0
# 1               Hotel        0
# 2  Seafood Restaurant        0
# 3               Hotel        0
# 4   Indian Restaurant        0

# %% [markdown]
# ### Mappping Restaurants, Resorts and Hotels within the 5 Clusters

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# set color scheme for the clusters
x = np.arange(num_clusters)
ys = [i + x + (i*x)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# %%
address = 'Nairobi, Kenya'

geolocator = Nominatim(user_agent="nairobi_explore")
location = geolocator.geocode(address)
nrb_latitude = location.latitude
nrb_longitude = location.longitude
print('The geograpical coordinate of Nairobi are {}, {}.'.format(latitude, longitude))

map_nairobi = folium.Map(location=[nrb_latitude, nrb_longitude], zoom_start=11)

# add markers to map
markers_colors = []
for lat, lon, poi, cluster in zip(nairobi_restaurants['Venue Latitude'], nairobi_restaurants['Venue Longitude'], nairobi_restaurants['Venue'], nairobi_restaurants['cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_nairobi)
       
map_nairobi
# Out:
# The geograpical coordinate of Nairobi are -1.2832533, 36.8172449.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Analysis of Each of the Clusters: We'll focus on 10 clusters out of the 25

# %%
## Lets have a look at the most dense clusters
nairobi_restaurants.groupby('cluster')['Venue'].count().plot(kind='bar')

# %% [markdown]
# **From a look of the density of the various clusters I will only focus on the clusters with highest density of Restaurants and Hotels** i.e. _0, 2, 5, 7, 11, 16, 18, 21, 22, 23_

# %% [markdown]
# ### Analysis of Cluster One: Nairobi CBD and Parklands

# %%
# Analysis of Cluster 1: Areas within Nairobi Central Business District
nairobi_restaurants[nairobi_restaurants.cluster == 0].head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 6   Parklands/Highridge              -1.263062               36.810629
# 7   Parklands/Highridge              -1.263062               36.810629
# 10  Parklands/Highridge              -1.263062               36.810629
# 17  Parklands/Highridge              -1.263062               36.810629
# 18  Parklands/Highridge              -1.263062               36.810629
#
#                      Venue  Venue Latitude  Venue Longitude  \
# 6     Southern Sun Mayfair       -1.262520        36.808652
# 7   La Maison Royale Hotel       -1.265329        36.808667
# 10  Ocean Basket @The Oval       -1.258567        36.805579
# 17    Villa Rosa Kempinski       -1.271530        36.808799
# 18                Chowpaty       -1.265624        36.805119
#
#         Venue Category  cluster
# 6                Hotel        0
# 7                Hotel        0
# 10  Seafood Restaurant        0
# 17               Hotel        0
# 18   Indian Restaurant        0

# %%
# Number of within Central Business District
cluster_one = nairobi_restaurants[nairobi_restaurants.cluster == 0]
cluster_one.shape[0]
# Out:
# 78

# %%
# Popular Neighbourhood in Cluster One
cluster_one["Neighborhood"].value_counts().plot(kind='bar')

# %%
cluster_one['Venue Category'].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 3: Areas around Kilimani Area

# %%
# Analysis of Cluster 3: 
nairobi_restaurants[nairobi_restaurants.cluster == 2].head()
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 118     Kilimani              -1.287442               36.784522
# 120     Kilimani              -1.287442               36.784522
# 121     Kilimani              -1.287442               36.784522
# 123     Kilimani              -1.287442               36.784522
# 124     Kilimani              -1.287442               36.784522
#
#                    Venue  Venue Latitude  Venue Longitude  \
# 118          Fogo Gaucho       -1.290710        36.782990
# 120  Osteria del Chianti       -1.288796        36.790005
# 121           O'Sinkirri       -1.288368        36.787048
# 123              Habesha       -1.292236        36.780006
# 124                G Pot       -1.291939        36.791417
#
#            Venue Category  cluster
# 118  Brazilian Restaurant        2
# 120    Italian Restaurant        2
# 121    Seafood Restaurant        2
# 123  Ethiopian Restaurant        2
# 124    African Restaurant        2

# %%
cluster_three = nairobi_restaurants[nairobi_restaurants.cluster == 2]
cluster_three.shape[0]
# Out:
# 30

# %%
# Popular Neighbourhood in Cluster One
cluster_three["Neighborhood"].value_counts().plot(kind='bar')

# %%
cluster_three['Venue Category'].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 6: Karen Area

# %%
nairobi_restaurants[nairobi_restaurants.cluster == 5].head()
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 234        Karen              -1.328375               36.704968
# 242        Karen              -1.328375               36.704968
# 247        Karen              -1.328375               36.704968
# 252        Karen              -1.328375               36.704968
# 255        Karen              -1.328375               36.704968
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 234                      Talisman       -1.322966        36.703348
# 242  Open House Restaurant  Karen       -1.323774        36.708288
# 247                      Que Pasa       -1.323020        36.706557
# 252                       Picazzo       -1.320131        36.703297
# 255                 Osteria Karen       -1.323881        36.700801
#
#                Venue Category  cluster
# 234  Mediterranean Restaurant        5
# 242         Indian Restaurant        5
# 247        Italian Restaurant        5
# 252        Spanish Restaurant        5
# 255        Italian Restaurant        5

# %%
cluster_six = nairobi_restaurants[nairobi_restaurants.cluster == 5]
cluster_six.shape[0]
# Out:
# 10

# %%
cluster_six['Venue Category'].value_counts().plot(kind='bar')

# %%
# Popular Neighbourhood in Cluster Six
cluster_six["Neighborhood"].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 8: Nairobi West, South C and Nairobi South Area

# %%
nairobi_restaurants[nairobi_restaurants.cluster == 7].head()
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 285  Nairobi West              -1.308702               36.823097
# 287  Nairobi West              -1.308702               36.823097
# 288  Nairobi West              -1.308702               36.823097
# 291  Nairobi West              -1.308702               36.823097
# 299  Nairobi West              -1.308702               36.823097
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 285       Mc Frys Nairobi West       -1.307823        36.823735
# 287                   Martha's       -1.312285        36.816696
# 288            Hill Park Hotel       -1.300217        36.820293
# 291                Mvuli House       -1.306063        36.823736
# 299  Nyayo Poolside Restaurant       -1.302631        36.824299
#
#            Venue Category  cluster
# 285  Fast Food Restaurant        7
# 287  Fast Food Restaurant        7
# 288                 Hotel        7
# 291                 Hotel        7
# 299            Restaurant        7

# %%
cluster_eight = nairobi_restaurants[nairobi_restaurants.cluster == 7]
cluster_eight.shape[0]
# Out:
# 25

# %%
cluster_eight['Venue Category'].value_counts().plot(kind='bar')

# %%
# Popular Neighbourhood in Cluster Six
cluster_eight["Neighborhood"].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 12: Roysambu, Kasarani, Zimmerman

# %%
nairobi_restaurants[nairobi_restaurants.cluster == 11].head()
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 443    Zimmerman              -1.210397               36.895221
# 455    Zimmerman              -1.210397               36.895221
# 464     Roysambu              -1.218840               36.886739
# 466     Roysambu              -1.218840               36.886739
# 472     Roysambu              -1.218840               36.886739
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 443              kenchic kasarani       -1.218220        36.896300
# 455             Car Wash Kasarani       -1.218015        36.898590
# 464    Thika Road Mall Food Court       -1.219415        36.887769
# 466             Safari Park Hotel       -1.224948        36.883962
# 472  Safari Park hotel and casino       -1.224980        36.883784
#
#            Venue Category  cluster
# 443  Fast Food Restaurant       11
# 455            Restaurant       11
# 464            Restaurant       11
# 466                 Hotel       11
# 472                 Hotel       11

# %%
cluster_12 = nairobi_restaurants[nairobi_restaurants.cluster == 11]
cluster_12.shape[0]
# Out:
# 14

# %%
cluster_12['Venue Category'].value_counts().plot(kind='bar')

# %%
# Popular Neighbourhood in Cluster Six
cluster_12["Neighborhood"].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 17: Kayole Area, Komarock

# %%
nairobi_restaurants[nairobi_restaurants.cluster == 16].head()
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 589    Kayole North              -1.265984               36.916946
# 594    Kayole North              -1.265984               36.916946
# 599  Kayole Central              -1.265984               36.916946
# 604  Kayole Central              -1.265984               36.916946
# 609    Kayole South              -1.265984               36.916946
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 589  Kwa Chipo za Aleki/Masha       -1.263702        36.914805
# 594               Wawaki Mall       -1.269216        36.911602
# 599  Kwa Chipo za Aleki/Masha       -1.263702        36.914805
# 604               Wawaki Mall       -1.269216        36.911602
# 609  Kwa Chipo za Aleki/Masha       -1.263702        36.914805
#
#            Venue Category  cluster
# 589  Fast Food Restaurant       16
# 594  Fast Food Restaurant       16
# 599  Fast Food Restaurant       16
# 604  Fast Food Restaurant       16
# 609  Fast Food Restaurant       16

# %%
cluster_17 = nairobi_restaurants[nairobi_restaurants.cluster == 16]
cluster_17.shape[0]
# Out:
# 7

# %%
cluster_12['Venue Category'].value_counts().plot(kind='bar')

# %%
# Popular Neighbourhood in Cluster Six
cluster_17["Neighborhood"].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 19: Embakasi Area

# %%
nairobi_restaurants[nairobi_restaurants.cluster == 18].head()
# Out:
#       Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 639  Upper Savanna              -1.324728               36.887724
# 647  Upper Savanna              -1.324728               36.887724
# 652  Lower Savanna              -1.324728               36.887724
# 660  Lower Savanna              -1.324728               36.887724
# 665       Embakasi              -1.324728               36.887724
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 639   Kenchic Imara Daima       -1.325542        36.887518
# 647  Chicken Inn-Embakasi       -1.328278        36.892707
# 652   Kenchic Imara Daima       -1.325542        36.887518
# 660  Chicken Inn-Embakasi       -1.328278        36.892707
# 665   Kenchic Imara Daima       -1.325542        36.887518
#
#            Venue Category  cluster
# 639  Fast Food Restaurant       18
# 647  Fast Food Restaurant       18
# 652  Fast Food Restaurant       18
# 660  Fast Food Restaurant       18
# 665  Fast Food Restaurant       18

# %%
cluster_19 = nairobi_restaurants[nairobi_restaurants.cluster == 18]
cluster_19.shape[0]
# Out:
# 10

# %%
cluster_19['Venue Category'].value_counts().plot(kind='bar')

# %%
# Popular Neighbourhood in Cluster Six
cluster_19["Neighborhood"].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 22: Makongeni and Hamsa

# %%
nairobi_restaurants[nairobi_restaurants.cluster == 21].head()
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 736    Makongeni               -1.28731               36.872107
# 737    Makongeni               -1.28731               36.872107
# 740    Makongeni               -1.28731               36.872107
# 755    Makongeni               -1.28731               36.872107
# 756    Makongeni               -1.28731               36.872107
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 736  Pop Inn Cafe - Jericho Market       -1.287709        36.873838
# 737                      Jerusalem       -1.285198        36.867929
# 740                 Jimlizer Hotel       -1.288470        36.877875
# 755            Creamy Inn-Buruburu       -1.294855        36.876833
# 756           Chicken Inn-Buruburu       -1.294855        36.876833
#
#            Venue Category  cluster
# 736  Fast Food Restaurant       21
# 737                Resort       21
# 740                 Hotel       21
# 755  Fast Food Restaurant       21
# 756  Fast Food Restaurant       21

# %%
cluster_22 = nairobi_restaurants[nairobi_restaurants.cluster == 21]
cluster_22.shape[0]
# Out:
# 7

# %%
cluster_22['Venue Category'].value_counts().plot(kind='bar')

# %%
# Popular Neighbourhood in Cluster 22
cluster_22["Neighborhood"].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 23: Eastleigh, Pumwani Area

# %%
nairobi_restaurants[nairobi_restaurants.cluster == 22].head()
# Out:
#         Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 782          Pumwani              -1.279758               36.844269
# 784          Pumwani              -1.279758               36.844269
# 785          Pumwani              -1.279758               36.844269
# 795  Eastleigh North              -1.277829               36.848683
# 796  Eastleigh North              -1.277829               36.848683
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 782                MPAMBE DISHES       -1.283997        36.847273
# 784  Grand Royal Hotel Eastleigh       -1.278988        36.851195
# 785           Nomad Palace Hotel       -1.279803        36.848178
# 795                MPAMBE DISHES       -1.283997        36.847273
# 796  Grand Royal Hotel Eastleigh       -1.278988        36.851195
#
#          Venue Category  cluster
# 782  African Restaurant       22
# 784               Hotel       22
# 785               Hotel       22
# 795  African Restaurant       22
# 796               Hotel       22

# %%
cluster_23 = nairobi_restaurants[nairobi_restaurants.cluster == 22]
cluster_23.shape[0]
# Out:
# 9

# %%
cluster_23['Venue Category'].value_counts().plot(kind='bar')

# %%
# Popular Neighbourhood in Cluster 23
cluster_23["Neighborhood"].value_counts().plot(kind='bar')

# %% [markdown]
# ### Analysis of Cluster 25: Huruma Area, Kiamiko

# %%
nairobi_restaurants[nairobi_restaurants.cluster == 24].head()
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1024       Huruma              -1.257646               36.872598
# 1032         Ngei              -1.259469               36.866781
# 1051     Kiamaiko              -1.253778               36.875732
#
#                        Venue  Venue Latitude  Venue Longitude Venue Category  \
# 1024  Jonsaga Travellers Inn       -1.260071        36.874302     Restaurant
# 1032  Jonsaga Travellers Inn       -1.260071        36.874302     Restaurant
# 1051  Jonsaga Travellers Inn       -1.260071        36.874302     Restaurant
#
#       cluster
# 1024       24
# 1032       24
# 1051       24

# %%
cluster_25 = nairobi_restaurants[nairobi_restaurants.cluster == 24]
cluster_25.shape[0]
# Out:
# 3

# %%
cluster_25['Venue Category'].value_counts().plot(kind='bar')

# %%
# Popular Neighbourhood in Cluster 23
cluster_25["Neighborhood"].value_counts().plot(kind='bar')

# %%
# cluster_three
# cluster_six
# cluster_eight
# cluster_12

f, ax = plt.subplots(3, 2, figsize=(30, 20))

cluster_one['Venue Category'].value_counts().plot(kind='barh', ax=ax[0][0])
ax[0][0].set_title("Nairobi CBD & Parklands")

cluster_three['Venue Category'].value_counts().plot(kind='barh', ax=ax[0][1])
ax[0][1].set_title("Kilimani Area")

cluster_six['Venue Category'].value_counts().plot(kind='barh', ax=ax[1][0])
ax[1][0].set_title("Karen Area")

cluster_eight['Venue Category'].value_counts().plot(kind='barh', ax=ax[1][1])
ax[1][1].set_title("Nairobi West/South C/Nairobi South Area")

cluster_12['Venue Category'].value_counts().plot(kind='barh', ax=ax[2][0])
ax[2][0].set_title("Roysambu/Kasarani/Zimmerman")

cluster_19['Venue Category'].value_counts().plot(kind='barh', ax=ax[2][1])
ax[2][1].set_title("Embakasi Area")
# Out:
# Text(0.5,1,'Embakasi Area')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From the analysis above I was able to Identify the following:
#  - Most restaurants in Nairobi are located within the Central Business District and Consitute the most preferred restaurants by Delegates or Political Guests to Kenya. Areas within Nairobi Area have a total of 78 Restaurants/Hotels
#  - Within Nairobi Central Business District, Karen area and Kilimani area: The number of international food serving restaurants are high, this is enough to give us some notion of population diversity within the area. It would therefore be best to launch a restaurant based on a given nationality within this areas e.g. Mexican, Spaniads, Indians, Japanese, Chinese, Ethiopian
#  - Nairobi CBD and Parklands have the highest number of Restaurants Density ie. 78 in total which I feel is already clogged with competition therefore it would be best to venture into Karen area and Kilimani area with is still low compared to CBD/Parklands i.e. 30 and 10 respectively
#  - Upcoming Areas for growth are Kasarani/Roysambu and Nairobi West/South C and Nairobi South area: Launching a Restaurant within this areas might prove to be a first mover advantage given the current growth in the number of international citizens within these areas.

# %% [markdown]
# ### The best Location to Launch a new Restaurant in Nairobi are as follows based on Categories

# %% [markdown]
# - For Multicultural Food restaurant the best bet for a Location would be around Kilimani Area and Karen Area. Eventhough there is a bit of competition based on the current number of restaurant offering international cuisines, this is the place to find the population with the multicultural taste buds.
# - For government focused, international delegates kind of hotel/restaurants - areas within and around the Central Business District and Parklands Areaa where the UN, US Embassy are located would be an ideal set up.
# - For quick meals and fast foods, areas around Nairobi West, South C would be the best zones given the party activities around these areas, clubs and casinos.

# %%
# Cluster 1 - Representing - Restaurant targeting delegates etc.
print(centermost_points.iloc[0])

# Cluster 3 - Three
centermost_points.iloc[2]

# Cluster 12
# Out:
# (-1.2715815728844049, 36.810034799891326)
# (-1.2911983519750818, 36.785221521640992)

# %% [markdown]
# ## Final Geographical Mapping based on Findings

# %%
address = 'Nairobi, Kenya'

geolocator = Nominatim(user_agent="nairobi_explore")
location = geolocator.geocode(address)
nrb_latitude = location.latitude
nrb_longitude = location.longitude
print('The geograpical coordinate of Nairobi are {}, {}.'.format(latitude, longitude))

map_nairobi = folium.Map(location=[nrb_latitude, nrb_longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(nairobi_restaurants['Venue Latitude'], nairobi_restaurants['Venue Longitude'], nairobi_restaurants['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#00A86B',
        fill_opacity=0.7).add_to(map_nairobi)
    
folium.Circle(
    location=[centermost_points.iloc[0][0], centermost_points.iloc[0][1]],
    radius=1000,
    popup='Restaurants targeting Delegates, Government Officials',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(map_nairobi)


folium.Circle(
    location=[centermost_points.iloc[2][0], centermost_points.iloc[2][1]],
    radius=1000,
    popup='Restaurants targeting Delegates, Government Officials',
    color='#ffa500',
    fill=True,
    fill_color='#ffa500'
).add_to(map_nairobi)


folium.Circle(
    location=[centermost_points.iloc[5][0], centermost_points.iloc[5][1]],
    radius=1000,
    popup='Restaurants targeting Delegates, Government Officials',
    color='#ffa500',
    fill=True,
    fill_color='#ffa500'
).add_to(map_nairobi)


folium.Circle(
    location=[centermost_points.iloc[11][0], centermost_points.iloc[11][1]],
    radius=1000,
    popup='Restaurants targeting Delegates, Government Officials',
    color='#ff69b4',
    fill=True,
    fill_color='#ff69b4'
).add_to(map_nairobi)


folium.Circle(
    location=[centermost_points.iloc[7][0], centermost_points.iloc[7][1]],
    radius=1000,
    popup='Restaurants targeting Delegates, Government Officials',
    color='#ff69b4',
    fill=True,
    fill_color='#ff69b4'
).add_to(map_nairobi)
    
map_nairobi
# Out:
# The geograpical coordinate of Nairobi are -1.2832533, 36.8172449.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Orange Location:** - Good for Restaurants focused on International Cuisines since there's a good number of international citizens as well as multicultured Nairobians.
# **Pink Location:** - These are upcoming regions with growing demand for restaurants and hotels - Good places to Launch a new Restaurants, it also has growing number of International Citizens.
# **Blue Location:** - This location is suitable for Delegates, International Citizens coming for political reasons, Embassy Guests etc.
